# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#settings
pd.set_option('display.max_columns', None)

# %%
#First datset
df_accepts = pd.read_csv('chefmozaccepts.csv', low_memory=False)

# %%
df_accepts
# Out:
#       placeID             Rpayment
# 0      135110                 cash
# 1      135110                 VISA
# 2      135110  MasterCard-Eurocard
# 3      135110     American_Express
# 4      135110     bank_debit_cards
# ...       ...                  ...
# 1309   132012          Diners_Club
# 1310   132002  MasterCard-Eurocard
# 1311   132002                 Visa
# 1312   132002     American_Express
# 1313   132002          Diners_Club
#
# [1314 rows x 2 columns]

# %%
df_accepts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   placeID   1314 non-null   int64
#  1   Rpayment  1314 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.7+ KB

# %%
len(df_accepts["placeID"].unique())
# Out:
# 615

# %%
df_accepts.isnull().sum()
# Out:
# placeID     0
# Rpayment    0
# dtype: int64

# %%
#second dataset
df_cuesine = pd.read_csv('chefmozcuisine.csv', low_memory=False)

# %%
df_cuesine
# Out:
#      placeID        Rcuisine
# 0     135110         Spanish
# 1     135109         Italian
# 2     135107  Latin_American
# 3     135106         Mexican
# 4     135105       Fast_Food
# ..       ...             ...
# 911   132005         Seafood
# 912   132004         Seafood
# 913   132003   International
# 914   132002         Seafood
# 915   132001   Dutch-Belgian
#
# [916 rows x 2 columns]

# %%
df_cuesine.isnull().sum()
# Out:
# placeID     0
# Rcuisine    0
# dtype: int64

# %%
#third dataset
df_hours = pd.read_csv('chefmozhours4.csv', low_memory=False)

# %%
df_hours
# Out:
#       placeID         hours                  days
# 0      135111  00:00-23:30;  Mon;Tue;Wed;Thu;Fri;
# 1      135111  00:00-23:30;                  Sat;
# 2      135111  00:00-23:30;                  Sun;
# 3      135110  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 4      135110  00:00-00:00;                  Sat;
# ...       ...           ...                   ...
# 2334   132012  12:00-22:00;                  Sun;
# 2335   132012  12:00-22:00;  Mon;Tue;Wed;Thu;Fri;
# 2336   132012  12:00-22:00;  Mon;Tue;Wed;Thu;Fri;
# 2337   132012  12:00-22:00;                  Sat;
# 2338   132012  12:00-22:00;                  Sat;
#
# [2339 rows x 3 columns]

# %%
df_hours.isnull().sum()
# Out:
# placeID    0
# hours      0
# days       0
# dtype: int64

# %%
df_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339 entries, 0 to 2338
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   placeID  2339 non-null   int64
#  1   hours    2339 non-null   object
#  2   days     2339 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 54.9+ KB

# %%
#fourth dataset
df_parking = pd.read_csv('chefmozparking.csv', low_memory=False)
df_parking
# Out:
#      placeID parking_lot
# 0     135111      public
# 1     135110        none
# 2     135109        none
# 3     135108        none
# 4     135107        none
# ..       ...         ...
# 697   132024      street
# 698   132023         fee
# 699   132023      public
# 700   132012      public
# 701   132012      street
#
# [702 rows x 2 columns]

# %%
df_parking.isnull().sum()
# Out:
# placeID        0
# parking_lot    0
# dtype: int64

# %%
#fifth dataset
df_geodata = pd.read_csv('geoplaces2.csv', low_memory=False,encoding='latin-1')
df_geodata
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
df_geodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   placeID         130 non-null    int64
#  1   latitude        130 non-null    float64
#  2   longitude       130 non-null    float64
#  3   the_geom_meter  130 non-null    object
#  4   name            130 non-null    object
#  5   address         130 non-null    object
#  6   city            130 non-null    object
#  7   state           130 non-null    object
#  8   country         130 non-null    object
#  9   fax             130 non-null    object
#  10  zip             130 non-null    object
#  11  alcohol         130 non-null    object
#  12  smoking_area    130 non-null    object
#  13  dress_code      130 non-null    object
#  14  accessibility   130 non-null    object
#  15  price           130 non-null    object
#  16  url             130 non-null    object
# ...

# %%
df_geodata1 = pd.read_csv('geoplaces.csv', low_memory=False,encoding='latin-1')

# %%
df_geodata1
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
df_geodata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   placeID         130 non-null    int64
#  1   latitude        130 non-null    float64
#  2   longitude       130 non-null    float64
#  3   the_geom_meter  130 non-null    object
#  4   name            130 non-null    object
#  5   city            130 non-null    object
#  6   state           130 non-null    object
#  7   country         130 non-null    object
#  8   alcohol         130 non-null    object
#  9   smoking_area    130 non-null    object
#  10  dress_code      130 non-null    object
#  11  accessibility   130 non-null    object
#  12  price           130 non-null    object
#  13  Rambience       130 non-null    object
#  14  franchise       130 non-null    object
#  15  area            130 non-null    object
# dtypes: float64(2), int64(1), object(13)
# ...

# %%
df_geodata1["name"].unique())
# Out:
# 129

# %%
df_geodata1["city"].unique()
# Out:
# array(['Cuernavaca', 's.l.p.', 'San Luis Potosi', 'victoria ', 'victoria',
#        'Cd Victoria', 'san luis potosi', 'Jiutepec', 'cuernavaca', 'slp',
#        'Soledad', 'san luis potos', 'san luis potosi ', 'Cd. Victoria',
#        'Ciudad Victoria', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=list(map(lambda x: x.strip(),df_geodata1["city"]))

# %%
df_geodata1["city"].unique()
# Out:
# array(['Cuernavaca', 's.l.p.', 'San Luis Potosi', 'victoria',
#        'Cd Victoria', 'san luis potosi', 'Jiutepec', 'cuernavaca', 'slp',
#        'Soledad', 'san luis potos', 'Cd. Victoria', 'Ciudad Victoria',
#        's.l.p'], dtype=object)

# %%
df_geodata1["city"]=list(map(lambda x: x.lower(),df_geodata1["city"]))

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 's.l.p.', 'san luis potosi', 'victoria',
#        'cd victoria', 'jiutepec', 'slp', 'soledad', 'san luis potos',
#        'cd. victoria', 'ciudad victoria', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("cd. victoria","cd victoria")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 's.l.p.', 'san luis potosi', 'victoria',
#        'cd victoria', 'jiutepec', 'slp', 'soledad', 'san luis potos',
#        'ciudad victoria', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("ciudad victoria","cd victoria")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 's.l.p.', 'san luis potosi', 'victoria',
#        'cd victoria', 'jiutepec', 'slp', 'soledad', 'san luis potos',
#        's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("san luis potos","san luis potosi")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 's.l.p.', 'san luis potosi', 'victoria',
#        'cd victoria', 'jiutepec', 'slp', 'soledad', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("cd victoria","victoria")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 's.l.p.', 'san luis potosi', 'victoria', 'jiutepec',
#        'slp', 'soledad', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("s.l.p.","slp")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 'slp', 'san luis potosi', 'victoria', 'jiutepec',
#        'soledad', 's.l.p'], dtype=object)

# %%
df_geodata1["city"]=df_geodata1["city"].replace("s.l.p","slp")

# %%
df_geodata1["city"].unique()
# Out:
# array(['cuernavaca', 'slp', 'san luis potosi', 'victoria', 'jiutepec',
#        'soledad'], dtype=object)

# %%
df_geodata1["state"]=list(map(lambda x: x.lower(),df_geodata1["state"]))

# %%
df_geodata1["state"].unique()
# Out:
# array(['morelos', 's.l.p.', 'san luis potosi', 'tamaulipas', 'slp',
#        'mexico', '?', 'san luis potos'], dtype=object)

# %%
df_geodata1["state"]=df_geodata1["state"].replace("s.l.p.","slp")

# %%
df_geodata1["state"].unique()
# Out:
# array(['morelos', 'slp', 'san luis potosi', 'tamaulipas', 'mexico', '?',
#        'san luis potos'], dtype=object)

# %%
df_geodata1["state"]=df_geodata1["state"].replace("san luis potos","san luis potosi")

# %%
df_geodata1["state"].unique()
# Out:
# array(['morelos', 'slp', 'san luis potosi', 'tamaulipas', 'mexico', '?'],
#       dtype=object)

# %%
df_geodata1
# Out:
#      placeID   latitude   longitude  \
# 0     134999  18.915421  -99.184871
# 1     132825  22.147392 -100.983092
# 2     135106  22.149709 -100.976093
# 3     132667  23.752697  -99.163359
# 4     132613  23.752903  -99.165076
# ..       ...        ...         ...
# 125   132866  22.141220 -100.931311
# 126   135072  22.149192 -101.002936
# 127   135109  18.921785  -99.235350
# 128   135019  18.875011  -99.159422
# 129   132877  22.135364 -100.934948
#
#                                         the_geom_meter  \
# 0    0101000020957F000088568DE356715AC138C0A525FC46...
# 1    0101000020957F00001AD016568C4858C1243261274BA5...
# 2    0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3    0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4    0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# ..                                                 ...
# 125  0101000020957F000013871838EC4A58C1B5DF74F8E396...
# 126  0101000020957F0000E7B79B1DB94758C1D29BC363D8AA...
# ...

# %%
df_geodata1.to_csv('geod.csv', index=False)

# %%
df_geodata1[]
